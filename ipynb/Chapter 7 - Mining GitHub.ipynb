# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 7: Mining GitHub: Inspecting Software Collaboration Habits, Building Interest Graphs, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# ## Example 1. Programmatically obtaining a personal API access token for accessing GitHub's API

# %%
import requests
from getpass import getpass
import json

username = '' # Your GitHub username
password = '' # Your GitHub password

# Note that credentials will be transmitted over a secure SSL connection
url = 'https://api.github.com/authorizations'
note = 'Mining the Social Web, 2nd Ed.'
post_data = {'scopes':['repo'],'note': note }

response = requests.post(
    url,
    auth = (username, password),
    data = json.dumps(post_data),
    )   

print "API response:", response.text
print
print "Your OAuth token is", response.json()['token']

# Go to https://github.com/settings/applications to revoke this token
# Out:
#  API response: {"message":"Bad credentials","documentation_url":"https://developer.github.com/v3"}
#
# Your OAuth token is
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-eea560010823> in <module>()
#      19 print "API response:", response.text
#      20 print
# ---> 21 print "Your OAuth token is", response.json()['token']
#      22
#      23 # Go to https://github.com/settings/applications to revoke this token
#
# KeyError: 'token'

# %% [markdown]
# ## Example 2. Making direct HTTP requests to GitHub's API

# %%
import json
import requests

# An unauthenticated request that doesn't contain an ?access_token=xxx query string
url = "https://api.github.com/repos/ptwobrussell/Mining-the-Social-Web/stargazers"
response = requests.get(url)

# Display one stargazer

print json.dumps(response.json()[0], indent=1)
print

# Display headers
for (k,v) in response.headers.items():
    print k, "=>", v

# %% [markdown]
# ## Example 3. Using PyGithub to query for stargazers of a particular repository

# %%
from github import Github

# XXX: Specify your own access token here

ACCESS_TOKEN = '31ecdab1c572a467b88b19d670e09aed9c431fa4'

# Specify a username and repository of interest for that user.

USER = 'ptwobrussell'
REPO = 'Mining-the-Social-Web'

client = Github(ACCESS_TOKEN, per_page=100)
user = client.get_user(USER)
repo = user.get_repo(REPO)

# Get a list of people who have bookmarked the repo.
# Since you'll get a lazy iterator back, you have to traverse
# it if you want to get the total number of stargazers.

stargazers = [ s for s in repo.get_stargazers() ]
print "Number of stargazers", len(stargazers)
# Out:
# Number of stargazers 1072

# %% [markdown]
# ## Example 4. Constructing a trivial property graph

# %%
# Create a directed graph

g = nx.DiGraph()

# Add an edge to the directed graph from X to Y

g.add_edge('X', 'Y')

# Print some statistics about the graph

print nx.info(g)
print

# Get the nodes and edges from the graph

print "Nodes:", g.nodes()
print "Edges:", g.edges()
print

# Get node properties

print "X props:", g.node['X']
print "Y props:", g.node['Y']

# Get edge properties

print "X=>Y props:", g['X']['Y']
print

# Update a node property

g.node['X'].update({'prop1' : 'value1'})
print "X props:", g.node['X']
print

# Update an edge property

g['X']['Y'].update({'label' : 'label1'})
print "X=>Y props:", g['X']['Y']
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 2
# Number of edges: 1
# Average in degree:   0.5000
# Average out degree:   0.5000
#
# Nodes: ['Y', 'X']
# Edges: [('X', 'Y')]
#
# X props: {}
# Y props: {}
# X=>Y props: {}
#
# X props: {'prop1': 'value1'}
#
# X=>Y props: {'label': 'label1'}

# %% [markdown]
# ## Example 5. Constructing an ego graph of a repository and its stargazers

# %%
# Expand the initial graph with (interest) edges pointing each direction for 
# additional people interested. Take care to ensure that user and repo nodes 
# do not collide by appending their type.

import networkx as nx

g = nx.DiGraph()
g.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)

for sg in stargazers:
    g.add_node(sg.login + '(user)', type='user')
    g.add_edge(sg.login + '(user)', repo.name + '(repo)', type='gazes')

# %% [markdown]
# ## Example 6. Introducing some handy graph operations

# %%
# Poke around in the current graph to get a better feel for how NetworkX works

print nx.info(g)
print
print g.node['Mining-the-Social-Web(repo)']
print g.node['ptwobrussell(user)']
print
print g['ptwobrussell(user)']['Mining-the-Social-Web(repo)']
# The next line would throw a KeyError since no such edge exists:
# print g['Mining-the-Social-Web(repo)']['ptwobrussell(user)']
print
print g['ptwobrussell(user)']
print g['Mining-the-Social-Web(repo)']
print
print g.in_edges(['ptwobrussell(user)'])
print g.out_edges(['ptwobrussell(user)'])
print
print g.in_edges(['Mining-the-Social-Web(repo)'])
print g.out_edges(['Mining-the-Social-Web(repo)'])
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1073
# Number of edges: 1072
# Average in degree:   0.9991
# Average out degree:   0.9991
#
# {'lang': u'JavaScript', 'owner': u'ptwobrussell', 'type': 'repo'}
# {'type': 'user'}
#
# {'type': 'gazes'}
#
# {u'Mining-the-Social-Web(repo)': {'type': 'gazes'}}
# {}
#
# []
# [('ptwobrussell(user)', u'Mining-the-Social-Web(repo)')]
#
# [(u'yobo000(user)', 'Mining-the-Social-Web(repo)'), (u'gregmoreno(user)', 'Mining-the-Social-Web(repo)'), (u'SathishRaju(user)', 'Mining-the-Social-Web(repo)'), (u'beinvest(user)', 'Mining-the-Social-Web(repo)'), (u'gawry(user)', 'Mining-the-Social-Web(repo)'), (u'decadef20(user)', 'Mining-the-Social-Web(repo)'), (u'darkfall(user)', 'Mining-the-Social-Web(repo)'), (u'daimajia(user)', 'Mining-the-Social-Web(repo)'), (u'phauly(user)', 'Mining-the-Social-Web(repo)'), (u'henri-nourel(user)', 'Mining-the-Social-Web(repo)'), (u'chihuanqi(user)', 'Mining-the-Social-Web(repo)'), (u'program247365(user)', 'Mining-the-Social-Web(repo)'), (u'xiaodiu2010(user)', 'Mining-the-Social-Web(repo)'), (u'yoghi(user)', 'Mining-the-Social-Web(repo)'), (u'dylanthomas(user)', 'Mining-the-Social-Web(repo)'), (u'EugeneLiang(user)', 'Mining-the-Social-Web(repo)'), (u'longislandicetea(user)', 'Mining-the-Social-Web(repo)'), (u'jagguli(user)', 'Mining-the-Social-Web(repo)'), (u'ConceptKreator(user)', 'Mining-the-Social-Web(repo)'), (u'rgtjf(user)', 'Mining-the-Social-Web(repo)'), (u'daseme(user)', 'Mining-the-Social-Web(repo)'), (u'keokilee(user)', 'Mining-the-Social-Web(repo)'), (u'azuranop(user)', 'Mining-the-Social-Web(repo)'), (u'enriquesanchezb(user)', 'Mining-the-Social-Web(repo)'), (u'chhzhangs(user)', 'Mining-the-Social-Web(repo)'), (u'jfca(user)', 'Mining-the-Social-Web(repo)'), (u'terry2012(user)', 'Mining-the-Social-Web(repo)'), (u'yy(user)', 'Mining-the-Social-Web(repo)'), (u'batasrki(user)', 'Mining-the-Social-Web(repo)'), (u'yhj8341(user)', 'Mining-the-Social-Web(repo)'), (u'zerojarvis(user)', 'Mining-the-Social-Web(repo)'), (u'royburns(user)', 'Mining-the-Social-Web(repo)'), (u'coodoing(user)', 'Mining-the-Social-Web(repo)'), (u'bootstrapt(user)', 'Mining-the-Social-Web(repo)'), (u'alexdiao(user)', 'Mining-the-Social-Web(repo)'), (u'ZoomQuiet(user)', 'Mining-the-Social-Web(repo)'), (u'trietptm(user)', 'Mining-the-Social-Web(repo)'), (u'bryantchan(user)', 'Mining-the-Social-Web(repo)'), (u'metllord(user)', 'Mining-the-Social-Web(repo)'), (u'flashus(user)', 'Mining-the-Social-Web(repo)'), (u'TomiToivio(user)', 'Mining-the-Social-Web(repo)'), (u'hammer(user)', 'Mining-the-Social-Web(repo)'), (u'paulbersch(user)', 'Mining-the-Social-Web(repo)'), (u'tranminhan(user)', 'Mining-the-Social-Web(repo)'), (u'amckenna(user)', 'Mining-the-Social-Web(repo)'), (u'zihaolucky(user)', 'Mining-the-Social-Web(repo)'), (u'khaing211(user)', 'Mining-the-Social-Web(repo)'), (u'thulio(user)', 'Mining-the-Social-Web(repo)'), (u'virajkulkarni14(user)', 'Mining-the-Social-Web(repo)'), (u'khurchla(user)', 'Mining-the-Social-Web(repo)'), (u'timmyshen(user)', 'Mining-the-Social-Web(repo)'), (u'jujubepalm(user)', 'Mining-the-Social-Web(repo)'), (u'acadopia(user)', 'Mining-the-Social-Web(repo)'), (u'lesbleus2007(user)', 'Mining-the-Social-Web(repo)'), (u'madsurgeon(user)', 'Mining-the-Social-Web(repo)'), (u'lemonad(user)', 'Mining-the-Social-Web(repo)'), (u'liuyeliufeng(user)', 'Mining-the-Social-Web(repo)'), (u'yiseul(user)', 'Mining-the-Social-Web(repo)'), (u'heptal(user)', 'Mining-the-Social-Web(repo)'), (u'yanhuaaoaoao(user)', 'Mining-the-Social-Web(repo)'), (u'tertsch(user)', 'Mining-the-Social-Web(repo)'), (u'shuhei(user)', 'Mining-the-Social-Web(repo)'), (u'NandoKstroNet(user)', 'Mining-the-Social-Web(repo)'), (u'mattharrison(user)', 'Mining-the-Social-Web(repo)'), (u'eduardocereto(user)', 'Mining-the-Social-Web(repo)'), (u'holys(user)', 'Mining-the-Social-Web(repo)'), (u'matiskay(user)', 'Mining-the-Social-Web(repo)'), (u'shanlalit(user)', 'Mining-the-Social-Web(repo)'), (u'andrewdanks(user)', 'Mining-the-Social-Web(repo)'), (u'liulinyang(user)', 'Mining-the-Social-Web(repo)'), (u'rossant(user)', 'Mining-the-Social-Web(repo)'), (u'tayashigenori(user)', 'Mining-the-Social-Web(repo)'), (u'Btibert3(user)', 'Mining-the-Social-Web(repo)'), (u'fakber(user)', 'Mining-the-Social-Web(repo)'), (u'Alexoner(user)', 'Mining-the-Social-Web(repo)'), (u'nine9s(user)', 'Mining-the-S ...

# %% [markdown]
# ## Example 7. Calculating degree, betweenness, and closeness centrality measures on the Krackhardt kite graph

# %%
from operator import itemgetter
from IPython.display import HTML
from IPython.core.display import display

display(HTML('<img src="files/resources/ch07-github/kite-graph.png" width="400px">'))

# The classic Krackhardt kite graph
kkg = nx.generators.small.krackhardt_kite_graph()

print "Degree Centrality"
print sorted(nx.degree_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True)
print

print "Betweenness Centrality"
print sorted(nx.betweenness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True)
print

print "Closeness Centrality"
print sorted(nx.closeness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True)
# Out:
# <img src="files/resources/ch07-github/kite-graph.png" width="400px">
# Degree Centrality
# [(3, 0.6666666666666666), (5, 0.5555555555555556), (6, 0.5555555555555556), (0, 0.4444444444444444), (1, 0.4444444444444444), (2, 0.3333333333333333), (4, 0.3333333333333333), (7, 0.3333333333333333), (8, 0.2222222222222222), (9, 0.1111111111111111)]
#
# Betweenness Centrality
# [(7, 0.38888888888888884), (5, 0.23148148148148148), (6, 0.23148148148148148), (8, 0.2222222222222222), (3, 0.10185185185185183), (0, 0.023148148148148143), (1, 0.023148148148148143), (2, 0.0), (4, 0.0), (9, 0.0)]
#
# Closeness Centrality
# [(5, 0.6428571428571429), (6, 0.6428571428571429), (3, 0.6), (7, 0.6), (0, 0.5294117647058824), (1, 0.5294117647058824), (2, 0.5), (4, 0.5), (8, 0.42857142857142855), (9, 0.3103448275862069)]

# %% [markdown]
# ## Example 8. Adding additional interest edges to the graph through the inclusion of "follows" edges

# %%
# Add (social) edges from the stargazers' followers. This can take a while 
# because of all of the potential API calls to GitHub. The approximate number
# of requests for followers for each iteration of this loop can be calculated as
# math.ceil(sg.get_followers() / 100.0) per the API returning up to 100 items
# at a time.

import sys

for i, sg in enumerate(stargazers):
    
    # Add "follows" edges between stargazers in the graph if any relationships exist
    try:
        for follower in sg.get_followers():
            if follower.login + '(user)' in g:
                g.add_edge(follower.login + '(user)', sg.login + '(user)', 
                           type='follows')
    except Exception, e: #ssl.SSLError
        print >> sys.stderr, "Encountered an error fetching followers for", \
                             sg.login, "Skipping."
        print >> sys.stderr, e

    print "Processed", i+1, " stargazers. Num nodes/edges in graph", \
          g.number_of_nodes(), "/", g.number_of_edges()
    print "Rate limit remaining", client.rate_limiting
# Out:
# Processed 1  stargazers. Num nodes/edges in graph 1073 / 1075
# Rate limit remaining (4986, 5000)
# Processed 2  stargazers. Num nodes/edges in graph 1073 / 1079
# Rate limit remaining (4985, 5000)
# Processed 3  stargazers. Num nodes/edges in graph 1073 / 1081
# Rate limit remaining (4984, 5000)
# Processed 4  stargazers. Num nodes/edges in graph 1073 / 1087
# Rate limit remaining (4982, 5000)
# Processed 5  stargazers. Num nodes/edges in graph 1073 / 1088
# Rate limit remaining (4981, 5000)
# Processed 6  stargazers. Num nodes/edges in graph 1073 / 1091
# Rate limit remaining (4980, 5000)
# Processed 7  stargazers. Num nodes/edges in graph 1073 / 1092
# Rate limit remaining (4979, 5000)
# Processed 8  stargazers. Num nodes/edges in graph 1073 / 1096
# Rate limit remaining (4977, 5000)
# Processed 9  stargazers. Num nodes/edges in graph 1073 / 1107
# Rate limit remaining (4973, 5000)
# Processed 10  stargazers. Num nodes/edges in graph 1073 / 1110
# Rate limit remaining (4972, 5000)
# Processed 11  stargazers. Num nodes/edges in graph 1073 / 1113
# Rate limit remaining (4971, 5000)
# Processed 12  stargazers. Num nodes/edges in graph 1073 / 1117
# Rate limit remaining (4970, 5000)
# Processed 13  stargazers. Num nodes/edges in graph 1073 / 1121
# Rate limit remaining (4969, 5000)
# Processed 14  stargazers. Num nodes/edges in graph 1073 / 1124
# Rate limit remaining (4968, 5000)
# Processed 15  stargazers. Num nodes/edges in graph 1073 / 1127
# Rate limit remaining (4967, 5000)
# Processed 16  stargazers. Num nodes/edges in graph 1073 / 1133
# Rate limit remaining (4966, 5000)
# Processed 17  stargazers. Num nodes/edges in graph 1073 / 1134
# Rate limit remaining (4965, 5000)
# Processed 18  stargazers. Num nodes/edges in graph 1073 / 1138
# Rate limit remaining (4964, 5000)
# Processed 19  stargazers. Num nodes/edges in graph 1073 / 1144
# Rate limit remaining (4963, 5000)
# Processed 20  stargazers. Num nodes/edges in graph 1073 / 1145
# Rate limit remaining (4962, 5000)
# Processed 21  stargazers. Num nodes/edges in graph 1073 / 1148
# Rate limit remaining (4959, 5000)
# Processed 22  stargazers. Num nodes/edges in graph 1073 / 1150
# Rate limit remaining (4958, 5000)
# Processed 23  stargazers. Num nodes/edges in graph 1073 / 1152
# Rate limit remaining (4957, 5000)
# Processed 24  stargazers. Num nodes/edges in graph 1073 / 1155
# Rate limit remaining (4956, 5000)
# Processed 25  stargazers. Num nodes/edges in graph 1073 / 1156
# Rate limit remaining (4955, 5000)
# Processed 26  stargazers. Num nodes/edges in graph 1073 / 1158
# Rate limit remaining (4954, 5000)
# Processed 27  stargazers. Num nodes/edges in graph 1073 / 1163
# Rate limit remaining (4953, 5000)
# Processed 28  stargazers. Num nodes/edges in graph 1073 / 1165
# Rate limit remaining (4952, 5000)
# Processed 29  stargazers. Num nodes/edges in graph 1073 / 1167
# Rate limit remaining (4951, 5000)
# Processed 30  stargazers. Num nodes/edges in graph 1073 / 1169
# Rate limit remaining (4950, 5000)
# Processed 31  stargazers. Num nodes/edges in graph 1073 / 1172
# Rate limit remaining (4949, 5000)
# Processed 32  stargazers. Num nodes/edges in graph 1073 / 1174
# Rate limit remaining (4948, 5000)
# Processed 33  stargazers. Num nodes/edges in graph 1073 / 1176
# Rate limit remaining (4947, 5000)
# Processed 34  stargazers. Num nodes/edges in graph 1073 / 1177
# Rate limit remaining (4946, 5000)
# Processed 35  stargazers. Num nodes/edges in graph 1073 / 1197
# Rate limit remaining (4940, 5000)
# Processed 36  stargazers. Num nodes/edges in graph 1073 / 1198
# Rate limit remaining (4939, 5000)
# Processed 37  stargazers. Num nodes/edges in graph 1073 / 1200
# Rate limit remaining (4938, 5000)
# Processed 38  stargazers. Num nodes/edges in graph 1073 / 1201
# Rate limit remaining (4937, 5000)
# Processed 39  stargazers. Num nodes/edges in graph 1073 / 1205
# Rate limit remaining (4935, 5000)
# Processed 40  stargazers. Num nodes/edges in graph 1073 / 1208
# Rate limit remaining (4934, 5000)
# Processed 41  stargazers. Num nodes/edges in graph 1073 / 1210
# Rate limit remaining (4933, 5000)
# Processed 42  stargazers. Num nodes/edges in graph 1073 / 1213
# Rate limit remaining (4932, 5000)
# Processed 43  stargazers. Num nodes/edges in graph 1073 / 1216
# Rate limit remaining (4931, 5000)
# Processed 44  stargazers. Num nodes/edges in graph 1073 / 1218
# Rate limit remaining (4930, 5000)
# Processed 45  stargazers. Num nodes/edges in graph 1073 / 1221
# Rate limit remaining (4929, 5000)
# Processed 46  stargazers. Num nodes/edges in graph 1073 / 1225
# Rate limit remaining (4927, 5000)
# Processed 47  stargazers. Num nodes/edges in graph 1073 / 1230
# Rate limit remaining (4924, 5000)
# Processed 48  stargazers. Num nodes/edges in graph 1073 / 1233
# Rate limit remaining (4923, 5000)
# Processed 49  stargazers. Num nodes/edges in graph 1073 / 1235
# Rate limit remaining (4922, 5000)
# Processed 50  stargazers. Num nodes/edges in graph 1073 / 1237
# Rate limit remaining (4921, 5000)
# Processed 51  stargazers. Num nodes/edges in graph 1073 / 1239
# Rate limit remaining (4920, 5000)
# Processed 52  stargazers. Num nodes/edges in graph 1073 / 1241
# Rate limit remaining (4919, 5000)
# Processed 53  stargazers. Num nodes/edges in graph 1073 / 1242
# Rate limit remaining (4918, 5000)
# Processed 54  stargazers. Num nodes/edges in graph 1073 / 1246
# Rate limit remaining (4917, 5000)
# Processed 55  stargazers. Num nodes/edges in graph 1073 / 1247
# Rate limit remaining (4916, 5000)
# Processed 56  stargazers. Num nodes/edges in graph 1073 / 1249
# Rate limit remaining (4915, 5000)
# Processed 57  stargazers. Num nodes/edges in graph 1073 / 1251
# Rate limit remaining (4914, 5000)
# Processed 58  stargazers. Num nodes/edges in graph 1073 / 1252
# Rate limit remaining (4913, 5000)
# Processed 59  stargazers. Num nodes/edges in graph 1073 / 1256
# Rate limit remaining (4911, 5000)
# Processed 60  stargazers. Num nodes/edges in graph 1073 / 1257
# Rate limit remaining (4910, 5000)
# Processed 61  stargazers. Num nodes/edges in graph 1073 / 1258
# Rate limit remaining (4909, 5000)
# Processed 62  stargazers. Num nodes/edges in graph 1073 / 1263
# Rate limit remaining (4907, 5000)
# Processed 63  stargazers. Num nodes/edges in graph 1073 / 1265
# Rate limit remaining (4906, 5000)
# Processed 64  stargazers. Num nodes/edges in graph 1073 / 1269
# Rate limit remaining (4905, 5000)
# Processed 65  stargazers. Num nodes/edges in graph 1073 / 1270
# Rate limit remaining (4904, 5000)
# Processed 66  stargazers. Num nodes/edges in graph 1073 / 1272
# Rate limit remaining (4903, 5000)
# Processed 67  stargazers. Num nodes/edges in graph 1073 / 1274
# Rate limit remaining (4902, 5000)
# Processed 68  stargazers. Num nodes/edges in graph 1073 / 1275
# Rate limit remaining (4901, 5000)
# Processed 69  stargazers. Num nodes/edges in graph 1073 / 1277
# Rate limit remaining (4900, 5000)
# Processed 70  stargazers. Num nodes/edges in graph 1073 / 1278
# Rate limit remaining (4899, 5000)
# Processed 71  stargazers. Num nodes/edges in graph 1073 / 1280
# Rate limit remaining (4898, 5000)
# Processed 72  stargazers. Num nodes/edges in graph 1073 / 1286
# Rate limit remaining (4897, 5000)
# Processed 73  stargazers. Num nodes/edges in graph 1073 / 1288
# Rate limit remaining (4896, 5000)
# Processed 74  stargazers. Num nodes/edges in graph 1073 / 1291
# Rate limit remaining (4895, 5000)
# Processed 75  stargazers. Num nodes/edges in graph 1073 / 1295
# Rate limit remaining (4893, 5000)
# Processed 76  stargazers. Num nodes/edges in graph 1073 / 1298
# Rate limit remaining (4892, 5000)
# Processed 77  stargazers. Num nodes/edges in graph 1073 / 1304
# Rate limit remaining (4890, 5000)
# Processed 78  stargazers. Num nodes/edges in graph 1073 / 1307
# Rate limit remaining (4888, 5000)
# Processed 79  stargazers. Num nodes/edges in graph 1073 / 1309
# Rate limit remaining (4887, 5000)
# Processed 80  stargazers. Num nodes/edges in graph 1073 / 1311
# Rate limit remaining (4886, 5000)
# Processed 81  stargazers. Num nodes/edges in graph 1073 / 1313
# Rate limit remaining (4885, 5000)
# Processed 82  stargazers. Num nodes/edges in graph 1073 / 1316
# Rate limit remaining (4884, 5000)
# Processed 83  stargazers. Num nodes/edges in graph 1073 / 1319
# Rate limit remaining (4883, 5000)
# Processed 84  stargazers. Num nodes/edges in graph 1073 / 1328
# Rate limit remaining (4880, 5000)
# Processed 85  stargazers. Num nodes/edges in graph 1073 / 1331
# Rate limit remaining (4879, 5000)
# Processed 86  stargazers. Num nodes/edges in graph 1073 / 1332
# Rate limit remaining (4878, 5000)
# Processed 87  stargazers. Num nodes/edges in graph 1073 / 1338
# Rate limit remaining (4876, 5000)
# Processed 88  stargazers. Num nodes/edges in graph 1073 / 1342
# Rate limit remaining (4875, 5000)
# Processed 89  stargazers. Num nodes/edges in graph 1073 / 1344
# Rate limit remaining (4874, 5000)
# Processed 90  stargazers. Num nodes/edges in graph 1073 / 1345
# Rate limit remaining (4873, 5000)
# Processed 91  stargazers. Num nodes/edges in graph 1073 / 1350
# Rate limit remaining (4872, 5000)
# Processed 92  stargazers. Num nodes/edges in graph 1073 / 1351
# Rate limit remaining (4871, 5000)
# Processed 93  stargazers. Num nodes/edges in graph 1073 / 1355
# Rate limit remaining (4870, 5000)
# Processed 94  stargazers. Num nodes/edges in graph 1073 / 1356
# Rate limit remaining (4869, 5000)
# Processed 95  stargazers. Num nodes/edges in graph 1073 / 1358
# Rate limit remaining (4868, 5000)
# Processed 96  stargazers. Num nodes/edges in graph 1073 / 1360
# Rate limit remaining (4867, 5000)
# Processed 97  stargazers. Num nodes/edges in graph 1073 / 1361
# Rate limit remaining (4866, 5000)
# Processed 98  stargazers. Num nodes/edges in graph 1073 / 1362
# Rate limit remaining (4865, 5000)
# Processed 99  stargazers. Num nodes/edges in graph 1073 / 1368
# Rate limit remaining (4861, 5000)
# Processed 100  stargazers. Num nodes/edges in graph 1073 / 1372
# Rate limit remaining (4860, 5000)
# Processed 101  stargazers. Num nodes/edges in graph 1073 / 1374
# Rate limit remaining (4859, 5000)
# Processed 102  stargazers. Num nodes/edges in graph 1073 / 1378
# Rate limit remaining (4857, 5000)
# Processed 103  stargazers. Num nodes/edges in graph 1073 / 1379
# Rate limit remaining (4856, 5000)
# Processed 104  stargazers. Num nodes/edges in graph 1073 / 1381
# Rate limit remaining (4855, 5000)
# **OUTPUT MUTED**

# %% [markdown]
# ## Example 9. Exploring the updated graph's "follows" edges

# %%
from operator import itemgetter
from collections import Counter

# Let's see how many social edges we added since last time.
print nx.info(g)
print

# The number of "follows" edges is the difference
print len([e for e in g.edges_iter(data=True) if e[2]['type'] == 'follows'])
print

# The repository owner is possibly one of the more popular users in this graph.
print len([e 
           for e in g.edges_iter(data=True) 
               if e[2]['type'] == 'follows' and e[1] == 'ptwobrussell(user)'])
print

# Let's examine the number of adjacent edges to each node
print sorted([n for n in g.degree_iter()], key=itemgetter(1), reverse=True)[:10]
print

# Consider the ratio of incoming and outgoing edges for a couple of users with 
# high node degrees...

# A user who follows many but is not followed back by many.

print len(g.out_edges('hcilab(user)'))
print len(g.in_edges('hcilab(user)'))
print

# A user who is followed by many but does not follow back.

print len(g.out_edges('ptwobrussell(user)'))
print len(g.in_edges('ptwobrussell(user)'))
print

c = Counter([e[1] for e in g.edges_iter(data=True) if e[2]['type'] == 'follows'])
popular_users = [ (u, f) for (u, f) in c.most_common() if f > 1 ]
print "Number of popular users", len(popular_users)
print "Top 10 popular users:", popular_users[:10]
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1073
# Number of edges: 2800
# Average in degree:   2.6095
# Average out degree:   2.6095
#
# 1728
#
# 121
#
# [(u'Mining-the-Social-Web(repo)', 1072), (u'angusshire(user)', 502), (u'ternsip(user)', 302), (u'kennethreitz(user)', 139), (u'ptwobrussell(user)', 122), (u'VagrantStory(user)', 103), (u'trietptm(user)', 69), (u'mcanthony(user)', 37), (u'daimajia(user)', 34), (u'JT5D(user)', 32)]
#
# 0
# 0
#
# 1
# 121
#
# Number of popular users 393
# Top 10 popular users: [(u'kennethreitz(user)', 136), (u'ptwobrussell(user)', 121), (u'daimajia(user)', 30), (u'hammer(user)', 20), (u'jkbrzt(user)', 19), (u'isnowfy(user)', 18), (u'japerk(user)', 18), (u'angusshire(user)', 12), (u'tswicegood(user)', 11), (u'ZoomQuiet(user)', 10)]

# %% [markdown]
# ## Example 10. Snapshotting (pickling) the graph's state to disk

# %%
# Save your work by serializing out (pickling) the graph
nx.write_gpickle(g, "github.gpickle.1")

# How to restore the graph...
# import networkx as nx
# g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.1")

# %% [markdown]
# ## Example 11. Applying centrality measures to the interest graph

# %%
from operator import itemgetter

# Create a copy of the graph so that we can iteratively mutate the copy
# as needed for experimentation

h = g.copy()

# Remove the seed of the interest graph, which is a supernode, in order
# to get a better idea of the network dynamics

h.remove_node('Mining-the-Social-Web(repo)')

# XXX: Remove any other nodes that appear to be supernodes.
# Filter any other nodes that you can by threshold
# criteria or heuristics from inspection.

# Display the centrality measures for the top 10 nodes


dc = sorted(nx.degree_centrality(h).items(), 
            key=itemgetter(1), reverse=True)

print "Degree Centrality"
print dc[:10]
print

bc = sorted(nx.betweenness_centrality(h).items(), 
            key=itemgetter(1), reverse=True)

print "Betweenness Centrality"
print bc[:10]
print

print "Closeness Centrality"
cc = sorted(nx.closeness_centrality(h).items(), 
            key=itemgetter(1), reverse=True)
print cc[:10]
# Out:
# Degree Centrality
# [(u'angusshire(user)', 0.4677871148459384), (u'ternsip(user)', 0.28104575163398693), (u'kennethreitz(user)', 0.1288515406162465), (u'ptwobrussell(user)', 0.11297852474323063), (u'VagrantStory(user)', 0.09523809523809525), (u'trietptm(user)', 0.06349206349206349), (u'mcanthony(user)', 0.03361344537815126), (u'daimajia(user)', 0.03081232492997199), (u'JT5D(user)', 0.028944911297852476), (u'hammer(user)', 0.02334267040149393)]
#
# Betweenness Centrality
# [(u'angusshire(user)', 0.012091000080807624), (u'trietptm(user)', 0.006552205024169214), (u'neriberto(user)', 0.0054023678795526945), (u'krmaxwell(user)', 0.004967387785851621), (u'evandrix(user)', 0.0024926100440877375), (u'miku(user)', 0.001463389093955339), (u'mcanthony(user)', 0.0010143897169882165), (u'matagus(user)', 0.0010039966142220127), (u'JT5D(user)', 0.0006518417902370376), (u'ternsip(user)', 0.0006138557829009442)]
#
# Closeness Centrality
# [(u'angusshire(user)', 0.4665079904794288), (u'ternsip(user)', 0.3606966809069997), (u'VagrantStory(user)', 0.29162017110367183), (u'trietptm(user)', 0.2719659051489172), (u'mcanthony(user)', 0.2639603674666924), (u'cwz8202(user)', 0.26034155597722963), (u'marctmiller(user)', 0.25784626949821465), (u'capitolmuckrakr(user)', 0.25359271752691653), (u'elviswf(user)', 0.25319492502883506), (u'NandoKstroNet(user)', 0.25299649640420435)]

# %% [markdown]
# ## Example 12. Adding starred repositories to the graph

# %%
# Let's add each stargazer's additional starred repos and add edges 
# to find additional interests.

MAX_REPOS = 500

for i, sg in enumerate(stargazers):
    print sg.login
    try:
        for starred in sg.get_starred()[:MAX_REPOS]: # Slice to avoid supernodes
            g.add_node(starred.name + '(repo)', type='repo', lang=starred.language, \
                       owner=starred.owner.login)
            g.add_edge(sg.login + '(user)', starred.name + '(repo)', type='gazes')
    except Exception, e: #ssl.SSLError:
        print "Encountered an error fetching starred repos for", sg.login, "Skipping."

    print "Processed", i+1, "stargazers' starred repos"
    print "Num nodes/edges in graph", g.number_of_nodes(), "/", g.number_of_edges()
    print "Rate limit", client.rate_limiting
# Out:
# rdempsey
# Processed 1 stargazers' starred repos
# Num nodes/edges in graph 1457 / 3184
# Rate limit (3467, 5000)
# frac
# Processed 2 stargazers' starred repos
# Num nodes/edges in graph 1571 / 3303
# Rate limit (3465, 5000)
# prb
# Processed 3 stargazers' starred repos
# Num nodes/edges in graph 1752 / 3489
# Rate limit (3463, 5000)
# mcroydon
# Processed 4 stargazers' starred repos
# Num nodes/edges in graph 2244 / 3987
# Rate limit (3458, 5000)
# batasrki
# Processed 5 stargazers' starred repos
# Num nodes/edges in graph 2290 / 4038
# Rate limit (3457, 5000)
# twleung
# Processed 6 stargazers' starred repos
# Num nodes/edges in graph 2765 / 4535
# Rate limit (3452, 5000)
# kevinchiu
# Processed 7 stargazers' starred repos
# Num nodes/edges in graph 3094 / 4912
# Rate limit (3448, 5000)
# nikolay
# Processed 8 stargazers' starred repos
# Num nodes/edges in graph 3582 / 5409
# Rate limit (3443, 5000)
# tswicegood
# Processed 9 stargazers' starred repos
# Num nodes/edges in graph 4021 / 5889
# Rate limit (3438, 5000)
# ngpestelos
# Processed 10 stargazers' starred repos
# Num nodes/edges in graph 4461 / 6379
# Rate limit (3433, 5000)
# darron
# Processed 11 stargazers' starred repos
# Num nodes/edges in graph 4881 / 6875
# Rate limit (3428, 5000)
# brunojm
# Processed 12 stargazers' starred repos
# Num nodes/edges in graph 5308 / 7374
# Rate limit (3423, 5000)
# rgaidot
# Processed 13 stargazers' starred repos
# Num nodes/edges in graph 5694 / 7873
# Rate limit (3418, 5000)
# openweb
# Processed 14 stargazers' starred repos
# Num nodes/edges in graph 6079 / 8367
# Rate limit (3413, 5000)
# shanlalit
# Processed 15 stargazers' starred repos
# Num nodes/edges in graph 6465 / 8865
# Rate limit (3408, 5000)
# hoffmann
# Processed 16 stargazers' starred repos
# Num nodes/edges in graph 6699 / 9165
# Rate limit (3404, 5000)
# nacht
# Processed 17 stargazers' starred repos
# Num nodes/edges in graph 7007 / 9591
# Rate limit (3399, 5000)
# hectoregm
# Processed 18 stargazers' starred repos
# Num nodes/edges in graph 7202 / 9841
# Rate limit (3396, 5000)
# tzuryby
# Processed 19 stargazers' starred repos
# Num nodes/edges in graph 7317 / 10012
# Rate limit (3393, 5000)
# marksands
# Processed 20 stargazers' starred repos
# Num nodes/edges in graph 7742 / 10510
# Rate limit (3388, 5000)
# wbzyl
# Processed 21 stargazers' starred repos
# Num nodes/edges in graph 8094 / 11004
# Rate limit (3383, 5000)
# sou
# Processed 22 stargazers' starred repos
# Num nodes/edges in graph 8187 / 11135
# Rate limit (3381, 5000)
# magnum
# Processed 23 stargazers' starred repos
# Num nodes/edges in graph 8523 / 11598
# Rate limit (3376, 5000)
# suzuki
# Processed 24 stargazers' starred repos
# Num nodes/edges in graph 8657 / 11764
# Rate limit (3374, 5000)
# tertsch
# Processed 25 stargazers' starred repos
# Num nodes/edges in graph 8925 / 12126
# Rate limit (3370, 5000)
# ymirpl
# Processed 26 stargazers' starred repos
# Num nodes/edges in graph 9043 / 12304
# Rate limit (3368, 5000)
# sebasmagri
# Processed 27 stargazers' starred repos
# Num nodes/edges in graph 9303 / 12669
# Rate limit (3364, 5000)
# galvez
# Processed 28 stargazers' starred repos
# Num nodes/edges in graph 9367 / 12763
# Rate limit (3363, 5000)
# paulbersch
# Processed 29 stargazers' starred repos
# Num nodes/edges in graph 9478 / 12946
# Rate limit (3361, 5000)
# georgebellos
# Processed 30 stargazers' starred repos
# Num nodes/edges in graph 9799 / 13442
# Rate limit (3356, 5000)
# acadopia
# Processed 31 stargazers' starred repos
# Num nodes/edges in graph 10167 / 13939
# Rate limit (3351, 5000)
# ggtr1138
# Processed 32 stargazers' starred repos
# Num nodes/edges in graph 10345 / 14187
# Rate limit (3348, 5000)
# program247365
# Processed 33 stargazers' starred repos
# Num nodes/edges in graph 10689 / 14687
# Rate limit (3343, 5000)
# edwelker
# Processed 34 stargazers' starred repos
# Num nodes/edges in graph 10782 / 14823
# Rate limit (3341, 5000)
# hammer
# Processed 35 stargazers' starred repos
# Num nodes/edges in graph 11206 / 15322
# Rate limit (3336, 5000)
# jengdal
# Processed 36 stargazers' starred repos
# Num nodes/edges in graph 11240 / 15382
# Rate limit (3335, 5000)
# brimbrom
# Processed 37 stargazers' starred repos
# Num nodes/edges in graph 11445 / 15762
# Rate limit (3331, 5000)
# gar
# Processed 38 stargazers' starred repos
# Num nodes/edges in graph 11459 / 15789
# Rate limit (3330, 5000)
# willi
# Processed 39 stargazers' starred repos
# Num nodes/edges in graph 11825 / 16289
# Rate limit (3325, 5000)
# gregmoreno
# Processed 40 stargazers' starred repos
# Num nodes/edges in graph 11928 / 16497
# Rate limit (3322, 5000)
# rays
# Processed 41 stargazers' starred repos
# Num nodes/edges in graph 11987 / 16599
# Rate limit (3320, 5000)
# rayleyva
# Processed 42 stargazers' starred repos
# Num nodes/edges in graph 12119 / 16790
# Rate limit (3317, 5000)
# paxan
# Processed 43 stargazers' starred repos
# Num nodes/edges in graph 12308 / 17154
# Rate limit (3313, 5000)
# eughenes
# Processed 44 stargazers' starred repos
# Num nodes/edges in graph 12346 / 17234
# Rate limit (3312, 5000)
# barce
# Processed 45 stargazers' starred repos
# Num nodes/edges in graph 12385 / 17295
# Rate limit (3311, 5000)
# abuiles
# Processed 46 stargazers' starred repos
# Num nodes/edges in graph 12697 / 17782
# Rate limit (3306, 5000)
# carhartl
# Processed 47 stargazers' starred repos
# Num nodes/edges in graph 12911 / 18184
# Rate limit (3301, 5000)
# jexchan
# Processed 48 stargazers' starred repos
# Num nodes/edges in graph 13196 / 18600
# Rate limit (3296, 5000)
# yasu00000
# Processed 49 stargazers' starred repos
# Num nodes/edges in graph 13507 / 19099
# Rate limit (3291, 5000)
# lsinger
# Processed 50 stargazers' starred repos
# Num nodes/edges in graph 13598 / 19243
# Rate limit (3289, 5000)
# yy
# Processed 51 stargazers' starred repos
# Num nodes/edges in graph 13636 / 19309
# Rate limit (3288, 5000)
# daemianmack
# Processed 52 stargazers' starred repos
# Num nodes/edges in graph 13726 / 19441
# Rate limit (3286, 5000)
# ricardoalmeida
# Processed 53 stargazers' starred repos
# Num nodes/edges in graph 13889 / 19704
# Rate limit (3283, 5000)
# gerad
# Processed 54 stargazers' starred repos
# Num nodes/edges in graph 13956 / 19824
# Rate limit (3281, 5000)
# amitagrawal
# Processed 55 stargazers' starred repos
# Num nodes/edges in graph 14111 / 20092
# Rate limit (3277, 5000)
# swinton
# Processed 56 stargazers' starred repos
# Num nodes/edges in graph 14311 / 20451
# Rate limit (3273, 5000)
# polonia
# Processed 57 stargazers' starred repos
# Num nodes/edges in graph 14358 / 20518
# Rate limit (3272, 5000)
# fozbaca
# Processed 58 stargazers' starred repos
# Num nodes/edges in graph 14511 / 20746
# Rate limit (3269, 5000)
# nborwankar
# Processed 59 stargazers' starred repos
# Num nodes/edges in graph 14577 / 20842
# Rate limit (3267, 5000)
# aljosa
# Processed 60 stargazers' starred repos
# Num nodes/edges in graph 14878 / 21341
# Rate limit (3262, 5000)
# macdet
# Processed 61 stargazers' starred repos
# Num nodes/edges in graph 14946 / 21439
# Rate limit (3260, 5000)
# Smerity
# Processed 62 stargazers' starred repos
# Num nodes/edges in graph 15218 / 21936
# Rate limit (3255, 5000)
# joepestro
# Processed 63 stargazers' starred repos
# Num nodes/edges in graph 15437 / 22431
# Rate limit (3250, 5000)
# phauly
# Processed 64 stargazers' starred repos
# Num nodes/edges in graph 15480 / 22486
# Rate limit (3249, 5000)
# shamiksharma
# Processed 65 stargazers' starred repos
# Num nodes/edges in graph 15522 / 22543
# Rate limit (3248, 5000)
# lg2046
# Processed 66 stargazers' starred repos
# Num nodes/edges in graph 15835 / 23035
# Rate limit (3243, 5000)
# omg
# Processed 67 stargazers' starred repos
# Num nodes/edges in graph 15848 / 23059
# Rate limit (3242, 5000)
# lzell
# Processed 68 stargazers' starred repos
# Num nodes/edges in graph 15925 / 23199
# Rate limit (3240, 5000)
# eduardocereto
# Processed 69 stargazers' starred repos
# Num nodes/edges in graph 15993 / 23363
# Rate limit (3238, 5000)
# kshimo69
# Processed 70 stargazers' starred repos
# Num nodes/edges in graph 16039 / 23435
# Rate limit (3237, 5000)
# natorro
# Processed 71 stargazers' starred repos
# Num nodes/edges in graph 16046 / 23450
# Rate limit (3236, 5000)
# abecciu
# Processed 72 stargazers' starred repos
# Num nodes/edges in graph 16305 / 23950
# Rate limit (3231, 5000)
# CaptSolo
# Processed 73 stargazers' starred repos
# Num nodes/edges in graph 16469 / 24193
# Rate limit (3228, 5000)
# clyfe
# Processed 74 stargazers' starred repos
# Num nodes/edges in graph 16747 / 24688
# Rate limit (3223, 5000)
# mahmoudimus
# Processed 75 stargazers' starred repos
# Num nodes/edges in graph 17116 / 25187
# Rate limit (3218, 5000)
# mkhDev
# Processed 76 stargazers' starred repos
# Num nodes/edges in graph 17242 / 25443
# Rate limit (3215, 5000)
# Kilian
# Processed 77 stargazers' starred repos
# Num nodes/edges in graph 17528 / 25942
# Rate limit (3210, 5000)
# stonegao
# Processed 78 stargazers' starred repos
# Num nodes/edges in graph 17800 / 26438
# Rate limit (3205, 5000)
# pcdinh
# Processed 79 stargazers' starred repos
# Num nodes/edges in graph 18151 / 26930
# Rate limit (3200, 5000)
# jacktang
# Processed 80 stargazers' starred repos
# Num nodes/edges in graph 18268 / 27148
# Rate limit (3197, 5000)
# Almad
# Processed 81 stargazers' starred repos
# Num nodes/edges in graph 18569 / 27636
# Rate limit (3192, 5000)
# sleeptillseven
# Processed 82 stargazers' starred repos
# Num nodes/edges in graph 18776 / 28125
# Rate limit (3187, 5000)
# Kudo
# Processed 83 stargazers' starred repos
# Num nodes/edges in graph 19060 / 28624
# Rate limit (3182, 5000)
# acdha
# Processed 84 stargazers' starred repos
# Num nodes/edges in graph 19382 / 29116
# Rate limit (3177, 5000)
# ticean
# Processed 85 stargazers' starred repos
# Num nodes/edges in graph 19665 / 29613
# Rate limit (3172, 5000)
# buffpojken
# Processed 86 stargazers' starred repos
# Num nodes/edges in graph 19811 / 29840
# Rate limit (3169, 5000)
# bnvk
# Processed 87 stargazers' starred repos
# Num nodes/edges in graph 20056 / 30208
# Rate limit (3165, 5000)
# zen4ever
# Processed 88 stargazers' starred repos
# Num nodes/edges in graph 20339 / 30708
# Rate limit (3160, 5000)
# bpeirce
# Processed 89 stargazers' starred repos
# Num nodes/edges in graph 20443 / 30914
# Rate limit (3157, 5000)
# metllord
# Processed 90 stargazers' starred repos
# Num nodes/edges in graph 20452 / 30934
# Rate limit (3156, 5000)
# macdiva
# Processed 91 stargazers' starred repos
# Num nodes/edges in graph 20711 / 31365
# Rate limit (3151, 5000)
# miukal
# Processed 92 stargazers' starred repos
# Num nodes/edges in graph 20792 / 31587
# Rate limit (3148, 5000)
# miyucy
# **OUTPUT MUTED**

# %% [markdown]
# **NOTE: Given that Example 12 is potentially a very time-consuming example to run, be sure to snapshot your work**

# %%
# Save your work by serializing out another snapshot of the graph
nx.write_gpickle(g, "github.gpickle.2")

#import networkx as nx
#g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.2")

# %% [markdown]
# Consider analysis similar to _Example 12_ here. Create a copy of the graph and be selective in pruning it or extracting subgraphs of interst.

# %%
#nx.write_gexf(g, "github2.gexf")
#nx.write_gml(g, "github2.gml")

from networkx.readwrite import json_graph
data = json_graph.node_link_data(g)
with open('graph.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
g = nx.read_gpickle("github.gpickle.2")

# %% [markdown]
# ## Example 13. Exploring the graph after updates with additional starred repositories

# %%
# Poke around: how to get users/repos
from operator import itemgetter

print nx.info(g)
print

# Get a list of repositories from the graph.

repos = [n for n in g.nodes_iter() if g.node[n]['type'] == 'repo']

# Most popular repos

print "Popular repositories"
print sorted([(n,d) 
              for (n,d) in g.in_degree_iter() 
                  if g.node[n]['type'] == 'repo'], \
             key=itemgetter(1), reverse=True)[:10]
print

# Projects gazed at by a user

print "Respositories that ptwobrussell has bookmarked"
print [(n,g.node[n]['lang']) 
       for n in g['ptwobrussell(user)'] 
           if g['ptwobrussell(user)'][n]['type'] == 'gazes']
print

# Programming languages for each user

print "Programming languages ptwobrussell is interested in"
print list(set([g.node[n]['lang'] 
                for n in g['ptwobrussell(user)'] 
                    if g['ptwobrussell(user)'][n]['type'] == 'gazes']))
print

# Find supernodes in the graph by approximating with a high number of 
# outgoing edges

print "Supernode candidates"
print sorted([(n, len(g.out_edges(n))) 
              for n in g.nodes_iter() 
                  if g.node[n]['type'] == 'user' and len(g.out_edges(n)) > 500], \
             key=itemgetter(1), reverse=True)
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 96833
# Number of edges: 233089
# Average in degree:   2.4071
# Average out degree:   2.4071
#
# Popular repositories
# [(u'Mining-the-Social-Web(repo)', 1072), (u'bootstrap(repo)', 260), (u'd3(repo)', 229), (u'dotfiles(repo)', 194), (u'free-programming-books(repo)', 164), (u'tensorflow(repo)', 160), (u'storm(repo)', 148), (u'requests(repo)', 139), (u'Mining-the-Social-Web-2nd-Edition(repo)', 132), (u'scrapy(repo)', 132)]
#
# Respositories that ptwobrussell has bookmarked
# [(u'gsoc-freebase-graph-importer(repo)', u'Java'), (u'schema(repo)', u'Clojure'), (u'dj-database-url(repo)', u'Python'), (u'stackdio(repo)', u'Python'), (u'x6502(repo)', u'C'), (u'TextBlob(repo)', u'Python'), (u'ipython-notebox(repo)', u'Ruby'), (u'networkx(repo)', u'Python'), (u'tiddlylisp(repo)', u'Python'), (u'fastly-py(repo)', u'Python'), (u'elasticsearch-py(repo)', u'Python'), (u'scikit-tensor(repo)', u'Python'), (u'webscalesql-5.6(repo)', u'C++'), (u'x-editable(repo)', u'JavaScript'), (u'premailer(repo)', u'Ruby'), (u'vowpal_wabbit(repo)', u'C++'), (u'CoreNLP(repo)', u'Java'), (u'torch-demos(repo)', u'Lua'), (u'echelon(repo)', u'Clojure'), (u'Mario-Level-1(repo)', u'Python'), (u'google-ngram-downloader(repo)', u'Python'), (u'gspread(repo)', u'Python'), (u'elephant(repo)', u'Python'), (u'Recipes-for-Mining-Twitter(repo)', u'JavaScript'), (u'django-tables2(repo)', u'Python'), (u'Crepe(repo)', u'Lua'), (u'django-froala-editor(repo)', u'JavaScript'), (u'qu(repo)', u'Ruby'), (u'Mining-the-Social-Web(repo)', u'JavaScript'), (u'django-zebra(repo)', u'Python'), (u'bootstrap-combobox(repo)', u'CSS'), (u'pdfminer(repo)', u'Python'), (u'django-url-shortener(repo)', u'Python'), (u'django-herokuapp(repo)', u'Python'), (u'portia(repo)', u'JavaScript'), (u'PyNES(repo)', u'Python'), (u'tab-snooze(repo)', u'JavaScript'), (u'django-bootstrap-wysiwyg(repo)', u'Python'), (u'pinax-theme-bootstrap(repo)', u'HTML'), (u'PayPal-APIs-Up-and-Running(repo)', u'Python'), (u'SimFinger(repo)', u'Objective-C'), (u'restricted-boltzmann-machines(repo)', u'Python'), (u'PyGithub(repo)', u'Python'), (u'django-pipeline(repo)', u'Python'), (u'html-email-resources(repo)', None), (u'django-heroku-memcacheify(repo)', u'Python'), (u'boot2docker(repo)', u'Shell'), (u'rescal.py(repo)', u'Python'), (u'django-shorturls(repo)', u'Python'), (u'yasp(repo)', u'JavaScript'), (u'ipython-docker(repo)', u'Shell'), (u'django-cacheback(repo)', u'Python'), (u'Legal-Forms(repo)', u'Python'), (u'PH7(repo)', u'C'), (u'celery-flower-heroku(repo)', None), (u'django-wysihtml5(repo)', u'Python'), (u'bookstore(repo)', u'Python'), (u'I8080(repo)', u'C'), (u'33-questions(repo)', None), (u'securegraph(repo)', u'Java'), (u'gitbook(repo)', u'JavaScript'), (u'micropython(repo)', u'C'), (u'bootstrap-wysihtml5(repo)', u'JavaScript'), (u'docker-jumpstart(repo)', u'CSS'), (u'templates(repo)', u'HTML'), (u'tomorrow-theme(repo)', u'CSS'), (u'plumbing(repo)', u'Clojure'), (u'treebank(repo)', u'Ruby'), (u'vagrant-aws(repo)', u'Ruby'), (u'alewrap(repo)', u'C++'), (u'tan-clustering(repo)', u'Python'), (u'lazysort(repo)', u'C'), (u'vagrant-omnibus(repo)', u'Ruby'), (u'wdb(repo)', u'Python'), (u'shash(repo)', u'C'), (u'pyelly(repo)', u'Python'), (u'cmacro(repo)', u'Common Lisp'), (u'camus(repo)', u'Java'), (u'requests-futures(repo)', u'Python'), (u'How-to-Make-a-Computer-Operating-System(repo)', u'C'), (u'AirChat(repo)', u'Perl'), (u'brain(repo)', u'JavaScript'), (u'Algorithmic-Alley(repo)', u'C#'), (u'quietnet(repo)', u'Python'), (u'news_site_frontend_omniauth(repo)', u'Ruby'), (u'redshift(repo)', u'Python'), (u'pinax-stripe(repo)', u'Python'), (u'django-social-auth(repo)', u'Python'), (u'envoy(repo)', u'Python'), (u'iTorch(repo)', u'Jupyter Notebook'), (u'PyStratus(repo)', u'Python'), (u'tablesorter(repo)', u'JavaScript'), (u'jusText(repo)', u'Python'), (u'rq(repo)', u'Python'), (u'Inquire(repo)', u'Python'), (u'ggplot(repo)', u'Python'), (u'django-compressor(repo)', u'Python'), (u'tmpnb(repo)', u'JavaScript'), (u'Tweet-Relevance(repo)', u'Python'), (u'ipython(repo)', u'Python'), (u't(repo)', u'Python'), (u'sendgrid-python(repo)', u'Python'), (u'python-social-auth(repo)', u'Python'), (u'applepy(repo)', u'Python'), (u'go(repo)', u'Go'), (u'notebooks(repo)', u'Jupyter Notebook'), (u'storm(repo)', u'Java'), (u'django-user-accounts(repo)', u'Python'), (u'behemoth(repo)', u'Java'), (u'parallel-coordinates(repo)', u'JavaScript'), (u'handsontable(repo)', u'JavaScript'), (u'django-sslify(repo)', u'Python'), ( ...
#
# Programming languages ptwobrussell is interested in
# [u'C', u'Shell', u'Java', None, u'CoffeeScript', u'Python', u'JavaScript', u'Jupyter Notebook', u'C++', u'Perl', u'Lua', u'Objective-C', u'HTML', u'Common Lisp', u'Go', u'Clojure', u'Ruby', u'CSS', u'C#']
#
# Supernode candidates
# [(u'angusshire(user)', 973), (u'ternsip(user)', 702), (u'VagrantStory(user)', 590), (u'trietptm(user)', 555), (u'JT5D(user)', 523), (u'rohithadassanayake(user)', 513), (u'cwz8202(user)', 507), (u'matagus(user)', 507), (u'Doppp(user)', 507), (u'marctmiller(user)', 506), (u'peicheng(user)', 506), (u'hanksudo(user)', 506), (u'abecciu(user)', 505), (u'hammer(user)', 505), (u'mtayseer(user)', 505), (u'ido(user)', 504), (u'mcroydon(user)', 504), (u'stonegao(user)', 504), (u'matiskay(user)', 504), (u'gawbul(user)', 504), (u'aburan28(user)', 504), (u'daimajia(user)', 504), (u'nimblemachine(user)', 504), (u'shuhei(user)', 503), (u'krmaxwell(user)', 502), (u'capitolmuckrakr(user)', 502), (u'motord(user)', 502), (u'mapio(user)', 502), (u'wenLiangcan(user)', 502), (u'samuelleach(user)', 502), (u'ahmdrefat(user)', 502), (u'dotpot(user)', 502), (u'jkbrzt(user)', 502), (u'cheekybastard(user)', 502), (u'rosco5(user)', 502), (u'andypiper(user)', 502), (u'jonathanyee(user)', 502), (u'zen4ever(user)', 502), (u'zmughal(user)', 502), (u'lingling2012(user)', 502), (u'barbietunnie(user)', 502), (u'miyucy(user)', 501), (u'brunojm(user)', 501), (u'timelyportfolio(user)', 501), (u'digvan(user)', 501), (u'takuan-osho(user)', 501), (u'nicib83(user)', 501), (u'Kudo(user)', 501), (u'alessioalex(user)', 501), (u'gaohailang(user)', 501), (u'seralf(user)', 501), (u'cb372(user)', 501), (u'rgaidot(user)', 501), (u'haraball(user)', 501), (u'xuxiandi(user)', 501), (u'andrewiiird(user)', 501), (u'evandrix(user)', 501), (u'twidi(user)', 501), (u'bcambel(user)', 501), (u'manboubird(user)', 501), (u'willi(user)', 501), (u'gabstehr(user)', 501), (u'program247365(user)', 501), (u'nikolay(user)', 501), (u'gr33ndata(user)', 501), (u'mahmoudimus(user)', 501)]

# %% [markdown]
# ## Example 14. Updating the graph to include nodes for programming languages

# %%
# Iterate over all of the repos, and add edges for programming languages 
# for each person in the graph. We'll also add edges back to repos so that 
# we have a good point to "pivot" upon.

repos = [n 
         for n in g.nodes_iter() 
             if g.node[n]['type'] == 'repo']

for repo in repos:
    lang = (g.node[repo]['lang'] or "") + "(lang)"
    
    stargazers = [u 
                  for (u, r, d) in g.in_edges_iter(repo, data=True) 
                     if d['type'] == 'gazes'
                 ]
    
    for sg in stargazers:
        g.add_node(lang, type='lang')
        g.add_edge(sg, lang, type='programs')
        g.add_edge(lang, repo, type='implements')

# %% [markdown]
# ## Example 15. Sample queries for the final graph

# %%
# Some stats

print nx.info(g)
print

# What languages exist in the graph?

print [n 
       for n in g.nodes_iter() 
           if g.node[n]['type'] == 'lang']
print

# What languages do users program with?
print [n 
       for n in g['ptwobrussell(user)'] 
           if g['ptwobrussell(user)'][n]['type'] == 'programs']

# What is the most popular programming language?
print "Most popular languages"
print sorted([(n, g.in_degree(n))
 for n in g.nodes_iter() 
     if g.node[n]['type'] == 'lang'], key=itemgetter(1), reverse=True)[:10]
print

# How many users program in a particular language?
python_programmers = [u 
                      for (u, l) in g.in_edges_iter('Python(lang)') 
                          if g.node[u]['type'] == 'user']
print "Number of Python programmers:", len(python_programmers)
print

javascript_programmers = [u for 
                          (u, l) in g.in_edges_iter('JavaScript(lang)') 
                              if g.node[u]['type'] == 'user']
print "Number of JavaScript programmers:", len(javascript_programmers)
print

# What users program in both Python and JavaScript?
print "Number of programmers who use JavaScript and Python"
print len(set(python_programmers).intersection(set(javascript_programmers)))

# Programmers who use JavaScript but not Python
print "Number of programmers who use JavaScript but not Python"
print len(set(javascript_programmers).difference(set(python_programmers)))

# XXX: Can you determine who is the most polyglot programmer?
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 97036
# Number of edges: 348826
# Average in degree:   3.5948
# Average out degree:   3.5948
#
# [u'PHP(lang)', u'PigLatin(lang)', u'Smalltalk(lang)', u'SRecode Template(lang)', u'FreeMarker(lang)', u'Shell(lang)', u'Red(lang)', u'Pascal(lang)', u'JavaScript(lang)', u'ApacheConf(lang)', u'Protocol Buffer(lang)', u'QML(lang)', u'PAWN(lang)', u'Objective-C(lang)', u'KiCad(lang)', u'Objective-J(lang)', u'F#(lang)', u'Scala(lang)', u'Jupyter Notebook(lang)', u'ASP(lang)', u'XML(lang)', u'MoonScript(lang)', u'Ruby(lang)', u'Eiffel(lang)', u'CartoCSS(lang)', u'C++(lang)', u'RAML(lang)', u'Common Lisp(lang)', u'SaltStack(lang)', u'Liquid(lang)', u'ChucK(lang)', u'Handlebars(lang)', u'AutoHotkey(lang)', u'Vue(lang)', u'Racket(lang)', u'Groovy(lang)', u'Processing(lang)', u'Lua(lang)', u'Smarty(lang)', u'Groff(lang)', u'VCL(lang)', u'Pure Data(lang)', u'Bro(lang)', u'Diff(lang)', u'Lex(lang)', u'NetLogo(lang)', u'POV-Ray SDL(lang)', u'OpenEdge ABL(lang)', u'Scheme(lang)', u'LOLCODE(lang)', u'AspectJ(lang)', u'Java(lang)', u'BitBake(lang)', u'Isabelle(lang)', u'Vala(lang)', u'AGS Script(lang)', u'Matlab(lang)', u'PLSQL(lang)', u'PureScript(lang)', u'Swift(lang)', u'OCaml(lang)', u'HLSL(lang)', u'Arduino(lang)', u'Brightscript(lang)', u'Eagle(lang)', u'Coq(lang)', u'ColdFusion(lang)', u'Julia(lang)', u'R(lang)', u'C(lang)', u'Nu(lang)', u'Max(lang)', u'VimL(lang)', u'Brainfuck(lang)', u'Thrift(lang)', u'GLSL(lang)', u'M(lang)', u'Haxe(lang)', u'IDL(lang)', u'Verilog(lang)', u'Grammatical Framework(lang)', u'SystemVerilog(lang)', u'Tcl(lang)', u'Web Ontology Language(lang)', u'SAS(lang)', u'Perl6(lang)', u'Zephir(lang)', u'NewLisp(lang)', u'Xtend(lang)', u'Mako(lang)', u'BlitzBasic(lang)', u'FORTRAN(lang)', u'Dart(lang)', u'Forth(lang)', u'PowerShell(lang)', u'AppleScript(lang)', u'Logos(lang)', u'API Blueprint(lang)', u'Propeller Spin(lang)', u'GDScript(lang)', u'Hack(lang)', u'APL(lang)', u'Clojure(lang)', u'eC(lang)', u'ActionScript(lang)', u'Objective-C++(lang)', u'Smali(lang)', u'Elixir(lang)', u'Gnuplot(lang)', u'Rust(lang)', u'PureBasic(lang)', u'SuperCollider(lang)', u'PLpgSQL(lang)', u'DIGITAL Command Language(lang)', u'Hy(lang)', u'Stan(lang)', u'Delphi(lang)', u'CSS(lang)', u'Mirah(lang)', '(lang)', u'XQuery(lang)', u'HTML(lang)', u'Go(lang)', u'wisp(lang)', u'D(lang)', u'Visual Basic(lang)', u'SMT(lang)', u'Mercury(lang)', u'Nginx(lang)', u'Frege(lang)', u'Batchfile(lang)', u'Puppet(lang)', u'E(lang)', u'Stata(lang)', u'LilyPond(lang)', u'VHDL(lang)', u'Perl(lang)', u'Assembly(lang)', u'CoffeeScript(lang)', u'Chapel(lang)', u'Oz(lang)', u'CMake(lang)', u'OpenSCAD(lang)', u'SQLPL(lang)', u'HCL(lang)', u'Opa(lang)', u'Cuda(lang)', u'Cucumber(lang)', u'SQL(lang)', u'NSIS(lang)', u'Ada(lang)', u'Fancy(lang)', u'Python(lang)', u'M4(lang)', u'nesC(lang)', u'TypeScript(lang)', u'Cycript(lang)', u'REALbasic(lang)', u'Apex(lang)', u'Idris(lang)', u'Awk(lang)', u'Kotlin(lang)', u'ANTLR(lang)', u'Standard ML(lang)', u'COBOL(lang)', u'Pony(lang)', u'Rebol(lang)', u'LiveScript(lang)', u'Haskell(lang)', u'HaXe(lang)', u'KRL(lang)', u'Squirrel(lang)', u'Nix(lang)', u'Gosu(lang)', u'SQF(lang)', u'PostScript(lang)', u'Limbo(lang)', u'XSLT(lang)', u'Metal(lang)', u'Game Maker Language(lang)', u'ooc(lang)', u'Bison(lang)', u'TeX(lang)', u'Agda(lang)', u'Makefile(lang)', u'Logtalk(lang)', u'Nimrod(lang)', u'Nemerle(lang)', u'Monkey(lang)', u"Cap'n Proto(lang)", u'Ragel in Ruby Host(lang)', u'AutoIt(lang)', u'Crystal(lang)', u'Emacs Lisp(lang)', u'Arc(lang)', u'Elm(lang)', u'Io(lang)', u'Mathematica(lang)', u'Inno Setup(lang)', u'Prolog(lang)', u'GCC Machine Description(lang)', u'C#(lang)', u'Erlang(lang)']
#
# [u'Java(lang)', u'HTML(lang)', u'Shell(lang)', u'Ruby(lang)', u'C++(lang)', '(lang)', u'Objective-C(lang)', u'CoffeeScript(lang)', u'Jupyter Notebook(lang)', u'C#(lang)', u'Lua(lang)', u'Go(lang)', u'Common Lisp(lang)', u'Perl(lang)', u'Clojure(lang)', u'C(lang)', u'JavaScript(lang)', u'Python(lang)', u'CSS(lang)']
# Most popular languages
# [(u'JavaScript(lang)', 1072), (u'Python(lang)', 966), ('(lang)', 921), (u'Java(lang)', 857), (u'Ruby(lang)', 835), (u'HTML(lang)', 813), (u'C++(lang)', 795), (u'C(lang)', 779), (u'Shell(lang)', 727), (u'CSS(lang)', 725)]
#
# Number of Python programmers: 966
#
# Number of JavaScript programmers: 1072
#
# Number of programmers who use JavaScript and Python
# 966
# Number of programmers who use JavaScript but not Python
# 106

# %% [markdown]
# **NOTE: Optionally, snapshot the final graph**

# %%
# Save your work by serializing out another snapshot of the graph
nx.write_gpickle(g, "github.gpickle.3")

#import networkx as nx
#g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.3")

# %% [markdown]
# ## Example 16. Graph visualization of the social network for the original interest graph

# %%
import os
import json
from IPython.display import IFrame
from IPython.core.display import display
from networkx.readwrite import json_graph

print "Stats on the full graph"
print nx.info(g)
print

# Create a subgraph from a collection of nodes. In this case, the
# collection is all of the users in the original interest graph

mtsw_users = [n for n in g if g.node[n]['type'] == 'user']
h = g.subgraph(mtsw_users)

print "Stats on the extracted subgraph"
print nx.info(h)

# Visualize the social network of all people from the original interest graph.

d = json_graph.node_link_data(h)
json.dump(d, open('resources/ch07-github/force.json', 'w'))


# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

# A D3 template for displaying the graph data.
viz_file = 'files/resources/ch07-github/force.html'

# Display the D3 visualization.

display(IFrame(viz_file, '100%', '600px'))
# Out:
# Stats on the full graph
# Name:
# Type: DiGraph
# Number of nodes: 97036
# Number of edges: 348826
# Average in degree:   3.5948
# Average out degree:   3.5948
#
# Stats on the extracted subgraph
# Name:
# Type: DiGraph
# Number of nodes: 1072
# Number of edges: 1728
# Average in degree:   1.6119
# Average out degree:   1.6119
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch07-github/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
mtsw_users = [n for n in g if g.node[n]['type'] == 'user']
h = g.subgraph(mtsw_users)

#nx.write_gexf(h, "github2.gexf")
#nx.write_gml(h, "github2.gml")
nx.write_graphml(h, "github2.graphml")
